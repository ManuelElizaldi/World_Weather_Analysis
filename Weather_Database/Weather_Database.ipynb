# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination. 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list. 
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a24ac4e4a9c4dfebf3377cb440b58290

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": weather_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bartica
# Processing Record 2 of Set 1 | bowen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | kuching
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | hofn
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | itimadpur
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | petauke
# Processing Record 14 of Set 1 | pisco
# Processing Record 15 of Set 1 | xichang
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | aksu
# Processing Record 19 of Set 1 | pangai
# Processing Record 20 of Set 1 | sovetskaya gavan
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | ojuelos de jalisco
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | saint-pierre
# Processing Record 30 of Set 1 | pangnirtung
# Processing Record 31 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 1 | klaksvik
# Processing Record 33 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 1 | kenai
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | cam ranh
# Processing Record 37 of Set 1 | diego de almagro
# Processing Record 38 of Set 1 | san cristobal
# Processing Record 39 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | ostrovnoy
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | naze
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | lima
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | kruisfontein
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | tateyama
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | fairlie
# Processing Record 3 of Set 2 | dunyapur
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | husavik
# Processing Record 6 of Set 2 | laguna
# Processing Record 7 of Set 2 | san andres
# Processing Record 8 of Set 2 | nemuro
# Processing Record 9 of Set 2 | tucuma
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | canton
# Processing Record 12 of Set 2 | matay
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | springbok
# Processing Record 15 of Set 2 | karratha
# Processing Record 16 of Set 2 | burns lake
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | hildburghausen
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | bredy
# Processing Record 22 of Set 2 | terrasini
# Processing Record 23 of Set 2 | lorengau
# Processing Record 24 of Set 2 | buchanan
# Processing Record 25 of Set 2 | linjiang
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | rostaq
# City not found. Skipping...
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | cheremukhovo
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | cockburn town
# Processing Record 34 of Set 2 | sumbe
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | gat
# Processing Record 38 of Set 2 | sioux lookout
# Processing Record 39 of Set 2 | yerbogachen
# Processing Record 40 of Set 2 | tabou
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | selma
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | ixtapa
# Processing Record 45 of Set 2 | panaba
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | severnoye
# Processing Record 48 of Set 2 | oktyabrskiy
# Processing Record 49 of Set 2 | phalombe
# Processing Record 50 of Set 2 | mehamn
# Processing Record 1 of Set 3 | kavaratti
# Processing Record 2 of Set 3 | manokwari
# Processing Record 3 of Set 3 | taoudenni
# Processing Record 4 of Set 3 | quatre cocos
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | vila do maio
# Processing Record 7 of Set 3 | san quintin
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | high level
# Processing Record 10 of Set 3 | chumikan
# Processing Record 11 of Set 3 | trollhattan
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | porto walter
# Processing Record 14 of Set 3 | punta arenas
# Processing Record 15 of Set 3 | new glasgow
# Processing Record 16 of Set 3 | polson
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | san patricio
# Processing Record 20 of Set 3 | henties bay
# Processing Record 21 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 22 of Set 3 | leningradskiy
# Processing Record 23 of Set 3 | bunbury
# Processing Record 24 of Set 3 | edd
# Processing Record 25 of Set 3 | hamilton
# Processing Record 26 of Set 3 | walvis bay
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | loreto
# Processing Record 29 of Set 3 | marsh harbour
# Processing Record 30 of Set 3 | hauterive
# Processing Record 31 of Set 3 | tautira
# Processing Record 32 of Set 3 | balod
# Processing Record 33 of Set 3 | korla
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | upernavik
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 3 | biltine
# Processing Record 39 of Set 3 | coahuayana
# Processing Record 40 of Set 3 | juan lacaze
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | santa maria
# Processing Record 43 of Set 3 | broken hill
# Processing Record 44 of Set 3 | faya
# Processing Record 45 of Set 3 | sidi ali
# Processing Record 46 of Set 3 | jamestown
# Processing Record 47 of Set 3 | weiser
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | srednekolymsk
# Processing Record 50 of Set 3 | tomatlan
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 2 of Set 4 | erzin
# Processing Record 3 of Set 4 | luanda
# Processing Record 4 of Set 4 | missoula
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 4 | nome
# Processing Record 8 of Set 4 | arman
# Processing Record 9 of Set 4 | tasiilaq
# Processing Record 10 of Set 4 | baracoa
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | coihaique
# Processing Record 13 of Set 4 | vilyuysk
# Processing Record 14 of Set 4 | lakes entrance
# Processing Record 15 of Set 4 | kudchi
# City not found. Skipping...
# Processing Record 16 of Set 4 | svetlaya
# Processing Record 17 of Set 4 | lata
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | port-gentil
# Processing Record 20 of Set 4 | liaozhong
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | cherskiy
# Processing Record 23 of Set 4 | mocuba
# Processing Record 24 of Set 4 | havre-saint-pierre
# Processing Record 25 of Set 4 | cortez
# Processing Record 26 of Set 4 | poros
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | yumen
# Processing Record 29 of Set 4 | beringovskiy
# Processing Record 30 of Set 4 | jasper
# Processing Record 31 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 4 | auki
# Processing Record 33 of Set 4 | ankang
# Processing Record 34 of Set 4 | pacific grove
# Processing Record 35 of Set 4 | oussouye
# Processing Record 36 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 4 | westport
# Processing Record 38 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 4 | balkanabat
# Processing Record 40 of Set 4 | talcahuano
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | clyde river
# Processing Record 43 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 4 | balabac
# Processing Record 45 of Set 4 | port blair
# Processing Record 46 of Set 4 | krylovskaya
# Processing Record 47 of Set 4 | trincomalee
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | katherine
# Processing Record 50 of Set 4 | omboue
# Processing Record 1 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 5 | wanning
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | axim
# Processing Record 5 of Set 5 | la ronge
# Processing Record 6 of Set 5 | anadyr
# Processing Record 7 of Set 5 | kimbe
# Processing Record 8 of Set 5 | zawadzkie
# Processing Record 9 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 10 of Set 5 | margate
# Processing Record 11 of Set 5 | dubbo
# Processing Record 12 of Set 5 | norman wells
# Processing Record 13 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 5 | lubango
# Processing Record 15 of Set 5 | kanigoro
# Processing Record 16 of Set 5 | dhana
# Processing Record 17 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 5 | los llanos de aridane
# Processing Record 19 of Set 5 | quime
# Processing Record 20 of Set 5 | novichikha
# Processing Record 21 of Set 5 | payakumbuh
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | mananjary
# Processing Record 24 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 5 | half moon bay
# Processing Record 26 of Set 5 | khorramshahr
# Processing Record 27 of Set 5 | alofi
# Processing Record 28 of Set 5 | nueve de julio
# Processing Record 29 of Set 5 | bambanglipuro
# Processing Record 30 of Set 5 | snezhnogorsk
# Processing Record 31 of Set 5 | shubarshi
# Processing Record 32 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 5 | conde
# Processing Record 34 of Set 5 | lebu
# Processing Record 35 of Set 5 | pochutla
# Processing Record 36 of Set 5 | vila velha
# Processing Record 37 of Set 5 | bermejo
# Processing Record 38 of Set 5 | aketi
# Processing Record 39 of Set 5 | beloha
# Processing Record 40 of Set 5 | skjervoy
# Processing Record 41 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 5 | chokurdakh
# Processing Record 43 of Set 5 | shetpe
# Processing Record 44 of Set 5 | adrar
# Processing Record 45 of Set 5 | yar-sale
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | burica
# City not found. Skipping...
# Processing Record 48 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 5 | narsaq
# Processing Record 50 of Set 5 | camopi
# Processing Record 1 of Set 6 | tchollire
# Processing Record 2 of Set 6 | bukama
# Processing Record 3 of Set 6 | rio gallegos
# Processing Record 4 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | himare
# Processing Record 6 of Set 6 | villa vazquez
# City not found. Skipping...
# Processing Record 7 of Set 6 | iqaluit
# Processing Record 8 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 6 | kahului
# Processing Record 10 of Set 6 | hovd
# Processing Record 11 of Set 6 | copiapo
# Processing Record 12 of Set 6 | pombas
# Processing Record 13 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 6 | qaanaaq
# Processing Record 15 of Set 6 | tombouctou
# Processing Record 16 of Set 6 | palmer
# Processing Record 17 of Set 6 | pevek
# Processing Record 18 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 6 | tanout
# Processing Record 21 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 6 | lompoc
# Processing Record 23 of Set 6 | sisimiut
# Processing Record 24 of Set 6 | dzaoudzi
# Processing Record 25 of Set 6 | waipawa
# Processing Record 26 of Set 6 | bathsheba
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 6 | north bend
# Processing Record 30 of Set 6 | chake chake
# Processing Record 31 of Set 6 | kargasok
# Processing Record 32 of Set 6 | nang rong
# Processing Record 33 of Set 6 | kisangani
# Processing Record 34 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 6 | puerto escondido
# Processing Record 36 of Set 6 | micheweni
# Processing Record 37 of Set 6 | pacifica
# Processing Record 38 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 6 | mount gambier
# Processing Record 40 of Set 6 | finale ligure
# Processing Record 41 of Set 6 | samarai
# Processing Record 42 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 6 | caravelas
# Processing Record 44 of Set 6 | thompson
# Processing Record 45 of Set 6 | bloomingdale
# Processing Record 46 of Set 6 | rocha
# Processing Record 47 of Set 6 | takoradi
# Processing Record 48 of Set 6 | galle
# Processing Record 49 of Set 6 | eenhana
# Processing Record 50 of Set 6 | brae
# Processing Record 1 of Set 7 | port lincoln
# Processing Record 2 of Set 7 | mazamari
# Processing Record 3 of Set 7 | sipe sipe
# Processing Record 4 of Set 7 | nalut
# Processing Record 5 of Set 7 | hervey bay
# Processing Record 6 of Set 7 | tutoia
# Processing Record 7 of Set 7 | mineiros
# Processing Record 8 of Set 7 | shimoda
# Processing Record 9 of Set 7 | kalmunai
# Processing Record 10 of Set 7 | juneau
# Processing Record 11 of Set 7 | aras
# Processing Record 12 of Set 7 | sao joao da barra
# Processing Record 13 of Set 7 | zhangye
# Processing Record 14 of Set 7 | makakilo city
# Processing Record 15 of Set 7 | kaeo
# Processing Record 16 of Set 7 | yining
# Processing Record 17 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 7 | cantanhede
# Processing Record 19 of Set 7 | astoria
# Processing Record 20 of Set 7 | mastic beach
# Processing Record 21 of Set 7 | atar
# Processing Record 22 of Set 7 | biggar
# Processing Record 23 of Set 7 | lishan
# Processing Record 24 of Set 7 | bambous virieux
# Processing Record 25 of Set 7 | batemans bay
# Processing Record 26 of Set 7 | abucay
# Processing Record 27 of Set 7 | mnogovershinnyy
# Processing Record 28 of Set 7 | ponta delgada
# Processing Record 29 of Set 7 | touros
# Processing Record 30 of Set 7 | neiafu
# Processing Record 31 of Set 7 | dingle
# Processing Record 32 of Set 7 | fredericksburg
# Processing Record 33 of Set 7 | vanimo
# Processing Record 34 of Set 7 | kenora
# Processing Record 35 of Set 7 | alice springs
# Processing Record 36 of Set 7 | luderitz
# Processing Record 37 of Set 7 | cayenne
# Processing Record 38 of Set 7 | nanortalik
# Processing Record 39 of Set 7 | northam
# Processing Record 40 of Set 7 | daru
# Processing Record 41 of Set 7 | behshahr
# Processing Record 42 of Set 7 | turukhansk
# Processing Record 43 of Set 7 | saurimo
# Processing Record 44 of Set 7 | sindand
# City not found. Skipping...
# Processing Record 45 of Set 7 | te anau
# Processing Record 46 of Set 7 | ulladulla
# Processing Record 47 of Set 7 | miri
# Processing Record 48 of Set 7 | saint-joseph
# Processing Record 49 of Set 7 | khandyga
# Processing Record 50 of Set 7 | saint-louis
# Processing Record 1 of Set 8 | lahaina
# Processing Record 2 of Set 8 | ust-maya
# Processing Record 3 of Set 8 | deputatskiy
# Processing Record 4 of Set 8 | aripuana
# Processing Record 5 of Set 8 | rawson
# Processing Record 6 of Set 8 | xuddur
# Processing Record 7 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 8 | xingcheng
# Processing Record 9 of Set 8 | aswan
# Processing Record 10 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 8 | kasane
# Processing Record 12 of Set 8 | jardim
# Processing Record 13 of Set 8 | shakawe
# Processing Record 14 of Set 8 | port hawkesbury
# Processing Record 15 of Set 8 | port hedland
# Processing Record 16 of Set 8 | kavieng
# Processing Record 17 of Set 8 | lancaster
# Processing Record 18 of Set 8 | tabas
# Processing Record 19 of Set 8 | mokhsogollokh
# Processing Record 20 of Set 8 | vila franca do campo
# Processing Record 21 of Set 8 | christchurch
# Processing Record 22 of Set 8 | turayf
# Processing Record 23 of Set 8 | zhigansk
# Processing Record 24 of Set 8 | fuquay-varina
# Processing Record 25 of Set 8 | komsomolskiy
# Processing Record 26 of Set 8 | seminole
# Processing Record 27 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 8 | stribro
# Processing Record 29 of Set 8 | teknaf
# Processing Record 30 of Set 8 | bilibino
# Processing Record 31 of Set 8 | ngorongoro
# Processing Record 32 of Set 8 | moose factory
# Processing Record 33 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 34 of Set 8 | morehead
# Processing Record 35 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 8 | vestmannaeyjar
# Processing Record 37 of Set 8 | havelock
# Processing Record 38 of Set 8 | comodoro rivadavia
# Processing Record 39 of Set 8 | meadow lake
# Processing Record 40 of Set 8 | progreso
# Processing Record 41 of Set 8 | wanaka
# Processing Record 42 of Set 8 | kangaatsiaq
# Processing Record 43 of Set 8 | san rafael
# Processing Record 44 of Set 8 | sarangani
# Processing Record 45 of Set 8 | bonfim
# Processing Record 46 of Set 8 | alihe
# Processing Record 47 of Set 8 | pitimbu
# Processing Record 48 of Set 8 | norilsk
# Processing Record 49 of Set 8 | codrington
# Processing Record 50 of Set 8 | lugo
# Processing Record 1 of Set 9 | steyr
# Processing Record 2 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 3 of Set 9 | sola
# Processing Record 4 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 5 of Set 9 | belmonte
# Processing Record 6 of Set 9 | synya
# Processing Record 7 of Set 9 | fortuna
# Processing Record 8 of Set 9 | charlestown
# Processing Record 9 of Set 9 | ures
# Processing Record 10 of Set 9 | zhovtneve
# Processing Record 11 of Set 9 | myanaung
# Processing Record 12 of Set 9 | san lawrenz
# Processing Record 13 of Set 9 | pueblo nuevo solistahuacan
# Processing Record 14 of Set 9 | inirida
# Processing Record 15 of Set 9 | saint-francois
# Processing Record 16 of Set 9 | iberia
# Processing Record 17 of Set 9 | puerto leguizamo
# Processing Record 18 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 19 of Set 9 | aranos
# Processing Record 20 of Set 9 | vardo
# Processing Record 21 of Set 9 | asau
# Processing Record 22 of Set 9 | santa cruz
# Processing Record 23 of Set 9 | nara
# Processing Record 24 of Set 9 | necochea
# Processing Record 25 of Set 9 | sao luis
# Processing Record 26 of Set 9 | sao jose da tapera
# Processing Record 27 of Set 9 | ormara
# Processing Record 28 of Set 9 | birakan
# Processing Record 29 of Set 9 | padang
# Processing Record 30 of Set 9 | zhangjiakou
# Processing Record 31 of Set 9 | meulaboh
# Processing Record 32 of Set 9 | tessalit
# Processing Record 33 of Set 9 | neringa
# Processing Record 34 of Set 9 | hokitika
# Processing Record 35 of Set 9 | bandarbeyla
# Processing Record 36 of Set 9 | arlit
# Processing Record 37 of Set 9 | taunggyi
# Processing Record 38 of Set 9 | sao filipe
# Processing Record 39 of Set 9 | talnakh
# Processing Record 40 of Set 9 | jingdezhen
# Processing Record 41 of Set 9 | babu
# Processing Record 42 of Set 9 | ust-nera
# Processing Record 43 of Set 9 | katsuura
# Processing Record 44 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 9 | mitsamiouli
# Processing Record 46 of Set 9 | okha
# Processing Record 47 of Set 9 | irun
# Processing Record 48 of Set 9 | tiksi
# Processing Record 49 of Set 9 | mathathane
# Processing Record 50 of Set 9 | vorobyevka
# Processing Record 1 of Set 10 | tadine
# Processing Record 2 of Set 10 | jizan
# Processing Record 3 of Set 10 | havoysund
# Processing Record 4 of Set 10 | aguimes
# Processing Record 5 of Set 10 | lakselv
# Processing Record 6 of Set 10 | porto novo
# Processing Record 7 of Set 10 | inongo
# Processing Record 8 of Set 10 | liverpool
# Processing Record 9 of Set 10 | biak
# Processing Record 10 of Set 10 | catarman
# Processing Record 11 of Set 10 | aykhal
# Processing Record 12 of Set 10 | ambon
# Processing Record 13 of Set 10 | nanakuli
# Processing Record 14 of Set 10 | aktau
# Processing Record 15 of Set 10 | qaqortoq
# Processing Record 16 of Set 10 | luba
# Processing Record 17 of Set 10 | cabatuan
# Processing Record 18 of Set 10 | villa union
# Processing Record 19 of Set 10 | westonaria
# Processing Record 20 of Set 10 | nouadhibou
# Processing Record 21 of Set 10 | banka
# Processing Record 22 of Set 10 | tura
# Processing Record 23 of Set 10 | nizhniy kuranakh
# Processing Record 24 of Set 10 | harper
# Processing Record 25 of Set 10 | seymchan
# Processing Record 26 of Set 10 | batagay-alyta
# Processing Record 27 of Set 10 | ekhabi
# Processing Record 28 of Set 10 | obluche
# City not found. Skipping...
# Processing Record 29 of Set 10 | binga
# Processing Record 30 of Set 10 | zhuhai
# Processing Record 31 of Set 10 | wamba
# Processing Record 32 of Set 10 | oranjestad
# Processing Record 33 of Set 10 | ouango
# Processing Record 34 of Set 10 | marzuq
# Processing Record 35 of Set 10 | general pico
# Processing Record 36 of Set 10 | benicarlo
# Processing Record 37 of Set 10 | coquimbo
# Processing Record 38 of Set 10 | leninskoye
# Processing Record 39 of Set 10 | bonnyville
# Processing Record 40 of Set 10 | george
# Processing Record 41 of Set 10 | andenes
# Processing Record 42 of Set 10 | visnes
# Processing Record 43 of Set 10 | lazaro cardenas
# Processing Record 44 of Set 10 | hohhot
# Processing Record 45 of Set 10 | rio pardo de minas
# Processing Record 46 of Set 10 | ahipara
# Processing Record 47 of Set 10 | columbus
# Processing Record 48 of Set 10 | praia
# Processing Record 49 of Set 10 | beregovoy
# Processing Record 50 of Set 10 | ilulissat
# Processing Record 1 of Set 11 | terney
# Processing Record 2 of Set 11 | ribeira grande
# Processing Record 3 of Set 11 | la rioja
# Processing Record 4 of Set 11 | nelson bay
# Processing Record 5 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 6 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 7 of Set 11 | eyl
# Processing Record 8 of Set 11 | colares
# Processing Record 9 of Set 11 | beni suef
# Processing Record 10 of Set 11 | harrison
# Processing Record 11 of Set 11 | krasnoselkup
# Processing Record 12 of Set 11 | grindavik
# Processing Record 13 of Set 11 | porto velho
# Processing Record 14 of Set 11 | camacha
# Processing Record 15 of Set 11 | evensk
# Processing Record 16 of Set 11 | agadir
# Processing Record 17 of Set 11 | sakakah
# Processing Record 18 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 11 | darhan
# Processing Record 20 of Set 11 | wuhan
# Processing Record 21 of Set 11 | bjelovar
# Processing Record 22 of Set 11 | zaysan
# Processing Record 23 of Set 11 | tiarei
# Processing Record 24 of Set 11 | kaufbeuren
# Processing Record 25 of Set 11 | sumkino
# Processing Record 26 of Set 11 | promysla
# City not found. Skipping...
# Processing Record 27 of Set 11 | mehran
# Processing Record 28 of Set 11 | lethem
# Processing Record 29 of Set 11 | poum
# Processing Record 30 of Set 11 | labuhan
# Processing Record 31 of Set 11 | solyanka
# Processing Record 32 of Set 11 | tilichiki
# Processing Record 33 of Set 11 | tucuman
# Processing Record 34 of Set 11 | kudahuvadhoo
# Processing Record 35 of Set 11 | geraldton
# Processing Record 36 of Set 11 | namibe
# Processing Record 37 of Set 11 | sanguem
# Processing Record 38 of Set 11 | karlstad
# Processing Record 39 of Set 11 | okhotsk
# Processing Record 40 of Set 11 | sri aman
# Processing Record 41 of Set 11 | cabedelo
# Processing Record 42 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 44 of Set 11 | saint george
# Processing Record 45 of Set 11 | hwange
# Processing Record 46 of Set 11 | ilinskiy
# Processing Record 47 of Set 11 | vieux fort
# Processing Record 48 of Set 11 | vila
# Processing Record 49 of Set 11 | mtsensk
# Processing Record 50 of Set 11 | leh
# Processing Record 1 of Set 12 | tome
# Processing Record 2 of Set 12 | peniche
# Processing Record 3 of Set 12 | saint-georges
# Processing Record 4 of Set 12 | beloretsk
# Processing Record 5 of Set 12 | dicabisagan
# Processing Record 6 of Set 12 | abancay
# Processing Record 7 of Set 12 | red deer
# Processing Record 8 of Set 12 | russell
# Processing Record 9 of Set 12 | shu
# Processing Record 10 of Set 12 | hasaki
# Processing Record 11 of Set 12 | vao
# Processing Record 12 of Set 12 | airai
# Processing Record 13 of Set 12 | wilmington
# Processing Record 14 of Set 12 | turbat
# Processing Record 15 of Set 12 | acapulco
# Processing Record 16 of Set 12 | doha
# Processing Record 17 of Set 12 | onega
# Processing Record 18 of Set 12 | bac lieu
# Processing Record 19 of Set 12 | kenitra
# Processing Record 20 of Set 12 | lebanon
# Processing Record 21 of Set 12 | bataipora
# Processing Record 22 of Set 12 | murakami
# Processing Record 23 of Set 12 | sibut
# Processing Record 24 of Set 12 | bismil
# Processing Record 25 of Set 12 | naryan-mar
# Processing Record 26 of Set 12 | kigorobya
# Processing Record 27 of Set 12 | chuy
# Processing Record 28 of Set 12 | bengkulu
# Processing Record 29 of Set 12 | olovi
# Processing Record 30 of Set 12 | timra
# Processing Record 31 of Set 12 | bosaso
# Processing Record 32 of Set 12 | ballina
# Processing Record 33 of Set 12 | wheatley
# Processing Record 34 of Set 12 | sakleshpur
# Processing Record 35 of Set 12 | pudozh
# Processing Record 36 of Set 12 | umred
# Processing Record 37 of Set 12 | fairbanks
# Processing Record 38 of Set 12 | virpur
# Processing Record 39 of Set 12 | tabuk
# Processing Record 40 of Set 12 | camana
# Processing Record 41 of Set 12 | gornopravdinsk
# Processing Record 42 of Set 12 | solnechnyy
# Processing Record 43 of Set 12 | sturlic
# Processing Record 44 of Set 12 | portland
# Processing Record 45 of Set 12 | wattegama
# Processing Record 46 of Set 12 | roma
# Processing Record 47 of Set 12 | krasnaya gora
# Processing Record 48 of Set 12 | kurumkan
# Processing Record 49 of Set 12 | tocache
# Processing Record 50 of Set 12 | izumo
# Processing Record 1 of Set 13 | iracoubo
# Processing Record 2 of Set 13 | mount vernon
# Processing Record 3 of Set 13 | avera
# Processing Record 4 of Set 13 | saint anthony
# Processing Record 5 of Set 13 | puerto del rosario
# Processing Record 6 of Set 13 | ustye
# Processing Record 7 of Set 13 | melfi
# Processing Record 8 of Set 13 | knysna
# Processing Record 9 of Set 13 | san francisco
# Processing Record 10 of Set 13 | banda aceh
# Processing Record 11 of Set 13 | skage
# City not found. Skipping...
# Processing Record 12 of Set 13 | berdigestyakh
# Processing Record 13 of Set 13 | palu
# Processing Record 14 of Set 13 | salalah
# Processing Record 15 of Set 13 | maceio
# Processing Record 16 of Set 13 | zlobin
# Processing Record 17 of Set 13 | matadi
# Processing Record 18 of Set 13 | polysayevo
# Processing Record 19 of Set 13 | waslala
# Processing Record 20 of Set 13 | urubicha
# Processing Record 21 of Set 13 | belyy yar
# Processing Record 22 of Set 13 | berdyuzhye
# City not found. Skipping...
# Processing Record 23 of Set 13 | atasu
# Processing Record 24 of Set 13 | dingzhou
# Processing Record 25 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 26 of Set 13 | chernyshevskiy
# Processing Record 27 of Set 13 | fougamou
# Processing Record 28 of Set 13 | ketchikan
# Processing Record 29 of Set 13 | igarka
# Processing Record 30 of Set 13 | constitucion
# Processing Record 31 of Set 13 | kununurra
# Processing Record 32 of Set 13 | mangrol
# Processing Record 33 of Set 13 | vaitape
# Processing Record 34 of Set 13 | manyana
# Processing Record 35 of Set 13 | madison
# Processing Record 36 of Set 13 | faanui
# Processing Record 37 of Set 13 | khani
# Processing Record 38 of Set 13 | loanda
# Processing Record 39 of Set 13 | tarko-sale
# Processing Record 40 of Set 13 | lithakia
# Processing Record 41 of Set 13 | kemijarvi
# Processing Record 42 of Set 13 | borascu
# Processing Record 43 of Set 13 | maracaibo
# Processing Record 44 of Set 13 | haines junction
# Processing Record 45 of Set 13 | mata grande
# Processing Record 46 of Set 13 | bone
# Processing Record 47 of Set 13 | milici
# Processing Record 48 of Set 13 | bima
# Processing Record 49 of Set 13 | sinnamary
# Processing Record 50 of Set 13 | wewak
# Processing Record 1 of Set 14 | jumla
# Processing Record 2 of Set 14 | umm ruwabah
# City not found. Skipping...
# Processing Record 3 of Set 14 | kharp
# Processing Record 4 of Set 14 | bam
# Processing Record 5 of Set 14 | carmen
# Processing Record 6 of Set 14 | shingu
# Processing Record 7 of Set 14 | yangambi
# Processing Record 8 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 9 of Set 14 | sangar
# Processing Record 10 of Set 14 | suda
# Processing Record 11 of Set 14 | gushikawa
# Processing Record 12 of Set 14 | genhe
# Processing Record 13 of Set 14 | cabra
# Processing Record 14 of Set 14 | sierpc
# Processing Record 15 of Set 14 | aljezur
# Processing Record 16 of Set 14 | aktas
# Processing Record 17 of Set 14 | garowe
# Processing Record 18 of Set 14 | mangan
# Processing Record 19 of Set 14 | hammerfest
# Processing Record 20 of Set 14 | port augusta
# Processing Record 21 of Set 14 | kongoussi
# Processing Record 22 of Set 14 | arrecife
# Processing Record 23 of Set 14 | am timan
# Processing Record 24 of Set 14 | damaturu
# Processing Record 25 of Set 14 | mount isa
# Processing Record 26 of Set 14 | guerrero negro
# Processing Record 27 of Set 14 | sorong
# Processing Record 28 of Set 14 | buraydah
# Processing Record 29 of Set 14 | pundaguitan
# Processing Record 30 of Set 14 | paita
# Processing Record 31 of Set 14 | champasak
# Processing Record 32 of Set 14 | kongolo
# Processing Record 33 of Set 14 | hazorasp
# Processing Record 34 of Set 14 | impfondo
# Processing Record 35 of Set 14 | rapid valley
# Processing Record 36 of Set 14 | boa vista
# Processing Record 37 of Set 14 | ankpa
# Processing Record 38 of Set 14 | corowa
# Processing Record 39 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 40 of Set 14 | herat
# Processing Record 41 of Set 14 | amboasary
# Processing Record 42 of Set 14 | escanaba
# Processing Record 43 of Set 14 | san policarpo
# Processing Record 44 of Set 14 | kasongo-lunda
# Processing Record 45 of Set 14 | susuman
# Processing Record 46 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 14 | puri
# Processing Record 48 of Set 14 | kletnya
# Processing Record 49 of Set 14 | orumiyeh
# Processing Record 50 of Set 14 | cobija
# Processing Record 1 of Set 15 | mersing
# Processing Record 2 of Set 15 | novikovo
# Processing Record 3 of Set 15 | shibetsu
# Processing Record 4 of Set 15 | nokaneng
# Processing Record 5 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 15 | mumford
# Processing Record 7 of Set 15 | alta floresta
# Processing Record 8 of Set 15 | manakara
# Processing Record 9 of Set 15 | kolpny
# Processing Record 10 of Set 15 | jian
# Processing Record 11 of Set 15 | tiznit
# Processing Record 12 of Set 15 | samana
# Processing Record 13 of Set 15 | dunedin
# Processing Record 14 of Set 15 | kaseda
# Processing Record 15 of Set 15 | kamaishi
# Processing Record 16 of Set 15 | kracheh
# City not found. Skipping...
# Processing Record 17 of Set 15 | shawinigan
# Processing Record 18 of Set 15 | opuwo
# Processing Record 19 of Set 15 | forestville
# Processing Record 20 of Set 15 | saint-augustin
# Processing Record 21 of Set 15 | nisia floresta
# Processing Record 22 of Set 15 | katobu
# Processing Record 23 of Set 15 | antalaha
# Processing Record 24 of Set 15 | sitangkai
# Processing Record 25 of Set 15 | kovacica
# Processing Record 26 of Set 15 | ust-omchug
# Processing Record 27 of Set 15 | asosa
# Processing Record 28 of Set 15 | gladstone
# Processing Record 29 of Set 15 | huangmei
# Processing Record 30 of Set 15 | bulgan
# Processing Record 31 of Set 15 | flin flon
# Processing Record 32 of Set 15 | vangaindrano
# Processing Record 33 of Set 15 | dolores
# Processing Record 34 of Set 15 | kaoma
# Processing Record 35 of Set 15 | san juan
# Processing Record 36 of Set 15 | bluefields
# Processing Record 37 of Set 15 | balykshi
# Processing Record 38 of Set 15 | pinyug
# Processing Record 39 of Set 15 | ucluelet
# Processing Record 40 of Set 15 | greenville
# Processing Record 41 of Set 15 | woodward
# Processing Record 42 of Set 15 | umm kaddadah
# Processing Record 43 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 15 | ouesso
# Processing Record 45 of Set 15 | praya
# Processing Record 46 of Set 15 | russellville
# Processing Record 47 of Set 15 | urumqi
# Processing Record 48 of Set 15 | marawi
# Processing Record 49 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 50 of Set 15 | pangkalanbuun
# Processing Record 1 of Set 16 | konongo
# Processing Record 2 of Set 16 | miandrivazo
# Processing Record 3 of Set 16 | ocampo
# Processing Record 4 of Set 16 | natchez
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Bartica   6.4000  -58.6167      75.2        94          40        6.91
# 1      Bowen -20.0167  148.2333      82.4        69          40       17.27
# 2  Cape Town -33.9258   18.4232      70.0        83          40        9.22
# 3    Kuching   1.5500  110.3333      73.4       100          40        2.30
# 4     Bethel  41.3712  -73.4140      17.6        45           1        9.22
#
#   Country Current Description
# 0      GY    scattered clouds
# 1      AU    scattered clouds
# 2      ZA    scattered clouds
# 3      MY       moderate rain
# 4      US           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
